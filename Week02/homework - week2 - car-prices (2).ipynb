# %% [markdown]
# # Assignment Week 2
#
# * Answer each question completely.
# * Include your code and summarize what you see in a brief narrative.
#
# __Charting:__
# Remember to make your charts as self-sufficient as possible (i.e., labels, titles, lack of clutter)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/ds602/car_prices/car_prices.csv', low_memory=False)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547043 non-null  object
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  object
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558837 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 68.2+ MB

# %% [markdown]
# # Data Description:
# - year: year the car was built (e.g., the model year)
# - make: the manufacturer.
# - model: specific model of the car
# - trim: subtype of the car model.
# - body: body style of the car.
# - transmission: type of transmission
# - state: state car is registered.
# - condition: numerical rating of the condition, higher is better.
# - odometer: number of miles the car has been driven.
# - color: color of the car.
# - interior: type of interior (e.g., seats).
# - mmr: estimated wholesale price of the car if auctioned.
# - sellingprice: actual sales price of the car.

# %% [markdown]
# ## Question 1. Determine the number of missing values in each column.

# %%
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65353
# vin                 4
# state               0
# condition       11794
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                 0
# sellingprice        0
# saledate            0
# dtype: int64

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# According to the results above, the columns for transmission, make, model, trim, body, and condition have the most null values, whereas the columns for year, state, seller, mmr, selling price, and sale date have no null values.

# %% [markdown]
# ## Question 2. Check the data types.
# - Which columns are coded to the incorrect type? If any, correct them.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547043 non-null  object
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  object
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558837 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 68.2+ MB

# %%
import pandas as pd
df['condition']=pd.to_numeric(df['condition'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  object
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558837 non-null  object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 68.2+ MB

# %%
df['mmr']=pd.to_numeric(df['mmr'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558811 non-null  float64
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558837 non-null  object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 68.2+ MB

# %%
import pandas as pd


df['saledate'] = pd.to_datetime(df['saledate'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558811 non-null  float64
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558811 non-null  datetime64[ns, UTC]
# ...

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# The data types of the 'condition' and'mmr' columns were initially 'object' and were converted to 'float64' .The'saledate' column, which was originally of type 'object', was transformed to 'datetime64' using pd.to_datetime() for suitable datetime handling. These modifications increase data accuracy and allow for more efficient processing and visualization.
#
# Additionally, the 'saledate' column was cleaned by coercing errors during conversion to datetime, ensuring that any problematic date values are handled gracefully. This enhances data consistency and prepares the dataset for time-based analyses.

# %% [markdown]
# ## Question 3. Analyze the `make` column.
# - Comment on what you observe.
# - Clean the column to reduce the number of unique values to as few as reasonably possible (no hard coding).
#
# Hint: What do you notice if you run this:
# ```python
# makes = df.make.unique().tolist()
# makes = [str(x).lower() for x in makes]
# sorted(makes)
# ```

# %%
makes = df.make.unique().tolist()
makes = [str(x).lower() for x in makes]
sorted(makes)
# Out:
# ['acura',
#  'acura',
#  'airstream',
#  'aston martin',
#  'audi',
#  'audi',
#  'bentley',
#  'bmw',
#  'bmw',
#  'buick',
#  'buick',
#  'cadillac',
#  'cadillac',
#  'chev truck',
#  'chevrolet',
#  'chevrolet',
#  'chrysler',
#  'chrysler',
#  'daewoo',
#  'dodge',
#  'dodge',
#  'dodge tk',
#  'dot',
#  'ferrari',
#  'fiat',
#  'fisker',
#  'ford',
#  'ford',
#  'ford tk',
#  'ford truck',
#  'geo',
#  'gmc',
#  'gmc',
#  'gmc truck',
#  'honda',
#  'honda',
#  'hummer',
#  'hyundai',
#  'hyundai',
#  'hyundai tk',
#  'infiniti',
#  'isuzu',
#  'jaguar',
#  'jeep',
#  'jeep',
#  'kia',
#  'kia',
#  'lamborghini',
#  'land rover',
#  'land rover',
#  'landrover',
#  'lexus',
#  'lexus',
#  'lincoln',
#  'lincoln',
#  'lotus',
#  'maserati',
#  'maserati',
#  'mazda',
#  'mazda',
#  'mazda tk',
#  'mercedes',
#  'mercedes-b',
#  'mercedes-benz',
#  'mercury',
#  'mercury',
#  'mini',
#  'mitsubishi',
#  'mitsubishi',
#  'nan',
#  'nissan',
#  'nissan',
#  'oldsmobile',
# ...

# %%
import re
replace_dict1 = {
    'chev truck': 'chevrolet',
    'dodge tk': 'dodge',
    'ford tk': 'ford',
    'ford truck': 'ford',
    'gmc truck': 'gmc',
    'hyundai tk': 'hyundai',
    'land rover': 'landrover',
    'mazda tk': 'mazda',
    'mercedes-b': 'mercedes',
    'mercedes-benz': 'mercedes',
    'vw': 'volkswagen',
    'nan': 'unknown',
    
    
}
df['make'].replace(replace_dict1, inplace=True)

unique_values = df['make'].unique()
print(unique_values)
len(unique_values)
# Out:
# ['Kia' 'BMW' 'Volvo' 'Nissan' 'Chevrolet' 'Audi' 'Ford' 'Hyundai' 'Buick'
#  'Cadillac' 'Acura' 'Lexus' 'Infiniti' 'Jeep' 'Mercedes-Benz' 'Mitsubishi'
#  'Mazda' 'MINI' 'Land Rover' 'Lincoln' 'lincoln' 'Jaguar' 'Volkswagen'
#  'Toyota' 'Subaru' 'Scion' 'Porsche' nan 'bmw' 'Dodge' 'FIAT' 'Chrysler'
#  'ford' 'Ferrari' 'Honda' 'GMC' 'mitsubishi' 'Ram' 'smart' 'chevrolet'
#  'Bentley' 'chrysler' 'pontiac' 'Pontiac' 'Saturn' 'Maserati' 'Mercury'
#  'HUMMER' 'landrover' 'cadillac' 'mercedes' 'mazda' 'toyota' 'lexus' 'gmc'
#  'honda' 'nissan' 'porsche' 'Saab' 'Suzuki' 'dodge' 'subaru' 'Oldsmobile'
#  'oldsmobile' 'hyundai' 'jeep' 'Isuzu' 'Geo' 'acura' 'volkswagen' 'suzuki'
#  'kia' 'audi' 'Rolls-Royce' 'maserati' 'mercury' 'buick' 'Daewoo'
#  'plymouth' 'Plymouth' 'Tesla' 'airstream' 'dot' 'Aston Martin' 'Fisker'
#  'Lamborghini' 'Lotus']
# 87

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# Data that was normalized included several formats and case-sensitive data.
# There are 97 distinct values in the make columns before cleaning.
# There are 87 distinct values in the make column after cleaning.

# %% [markdown]
# ## Question 4. Analyze the relationship between the wholeprice `mmr` and the `salesprice`.
# - What is the overall correlation?
# - What happens to the correlation as you increase the maximum selling price window (e.g., 0-10000, 0-20000,...)?
# - Create a scatter plot with the relationship.
# - Create a graph that shows how the correlation changes.

# %%
correlation = df['mmr'].corr(df['sellingprice'])
print( correlation)
# Out:
# 0.9836337168977236

# %%
selling_price_window= []
max_selling_price = max(df['sellingprice'])
incre1 = 10000
df1=df[0:10000]
df1['selling_price_window'] = range(0,incre1)
incre2=20000
df2=df[0:20000]
df2['selling_price_window'] = range(0,incre2)
corr1 = df1['mmr'].corr(df1['selling_price_window'])
print('0:10000: ', corr1)
corr2= df2['mmr'].corr(df2['selling_price_window'])
print('0:20000', corr2)
# Out:
# 0:10000:  -0.10659627653836662
# 0:20000 -0.23991395309970562
# C:\Users\RESHMA CHOWDARY\AppData\Local\Temp\ipykernel_9088\4148903509.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['selling_price_window'] = range(0,incre1)
# C:\Users\RESHMA CHOWDARY\AppData\Local\Temp\ipykernel_9088\4148903509.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['selling_price_window'] = range(0,incre2)

# %%
import seaborn as sns
sns.scatterplot(data=df, x='mmr',y='sellingprice')
plt.title('Scatter plot between mmr and selling price')
plt.xlabel('mmr')
plt.ylabel('selling price')
plt.show()

# %%
import seaborn as sns
sns.lineplot(data=df, x='mmr',y='sellingprice')
plt.title('Line plot between mmr and selling price')
plt.xlabel('mmr')
plt.ylabel('selling price')
plt.show()

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# 1.The initial correlation between 'mmr' and 'sellingprice' is strong . As the selling price window widens from 0 to 20,000, the correlation weakens.
#
# 2.This suggests a decresing negative relationship between 'mmr' and 'sellingprice' with broader price ranges.
#
# 3.The scatter and line plots visually shows these correlation patterns across various selling price windows.

# %% [markdown]
# ## Question 5. How does the distribution of `salesprice` vary by make for cars made between 2010-2015?
# - Use the 10 most common makes (your cleaned version of this column).
# - Create a graph that answers this question.

# %%
top_common_cars = df['make'].value_counts().nlargest(10).index.tolist()
top_common_cars
# Out:
# ['Ford',
#  'Chevrolet',
#  'Nissan',
#  'Toyota',
#  'Dodge',
#  'Honda',
#  'Hyundai',
#  'BMW',
#  'Kia',
#  'Chrysler']

# %%
import pandas as pd
def fetch_year(date):
    return date.year

df['saleyear'] = df['saledate'].apply(fetch_year)
print(df['saleyear'])
year2010_15 = df.loc[(df['saleyear'] >= 2010) & (df['saleyear'] <= 2015)]
year2010_15 = year2010_15.loc[year2010_15['make'].isin(top_common_cars)]
# Out:
# 0         2014.0
# 1         2014.0
# 2         2015.0
# 3         2015.0
# 4         2014.0
#            ...
# 558832    2015.0
# 558833    2015.0
# 558834    2015.0
# 558835    2015.0
# 558836    2015.0
# Name: saleyear, Length: 558837, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
sns.boxplot(data=year_2010_15, x='make', y=np.log(year_2010_15['sellingprice']))
plt.title('Selling Price Distribution for Each Car Make')
plt.xlabel('Car Make')
plt.ylabel('Log Selling Price')
plt.show()

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# BMW and Mercedes exhibit the highest median selling prices with a wide range of prices, while Kia has the lowest median selling price. All car makes show price variability with numerous outliers indicating both unusually low and high-priced vehicles within each brand
